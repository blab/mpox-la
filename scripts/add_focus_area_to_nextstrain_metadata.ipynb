# %%
import pandas as pd
import numpy as np 
import altair as alt
from altair import datum

import random

# %%
metadata = pd.read_csv("../mpox_build/phylogenetic/data/metadata.tsv", sep = "\t", parse_dates= ['date'])

# %%
metadata.columns
# Out:
# Index(['accession', 'genbank_accession_rev', 'strain', 'date', 'region',
#        'country', 'division', 'location', 'host', 'date_submitted',
#        'sra_accession', 'abbr_authors', 'authors', 'institution', 'clade',
#        'outbreak', 'lineage', 'coverage', 'missing_data', 'divergence',
#        'nonACGTN', 'QC_missing_data', 'QC_mixed_sites', 'QC_rare_mutations',
#        'QC_frame_shifts', 'QC_stop_codons', 'frame_shifts',
#        'is_reverse_complement'],
#       dtype='object')

# %%
metadata.head()
# Out:
#      accession genbank_accession_rev                strain        date  \
# 0     OP890421            OP890421.1  MPXV_USA_2022_MA0063  2022-XX-XX
# 1     OP890422            OP890422.1  MPXV_USA_2022_MA0064  2022-XX-XX
# 2     OP890423            OP890423.1  MPXV_USA_2022_MA0065  2022-XX-XX
# 3     OP890424            OP890424.1  MPXV_USA_2022_MA0066  2022-XX-XX
# 4     OP890425            OP890425.1  MPXV_USA_2022_MA0067  2022-XX-XX
# ...        ...                   ...                   ...         ...
# 8549  OP890416            OP890416.1  MPXV_USA_2022_MA0058  2022-XX-XX
# 8550  OP890417            OP890417.1  MPXV_USA_2022_MA0059  2022-XX-XX
# 8551  OP890418            OP890418.1  MPXV_USA_2022_MA0060  2022-XX-XX
# 8552  OP890419            OP890419.1  MPXV_USA_2022_MA0061  2022-XX-XX
# 8553  OP890420            OP890420.1  MPXV_USA_2022_MA0062  2022-XX-XX
#
#              region country       division location          host  \
# 0     North America     USA  Massachusetts      NaN  Homo sapiens
# 1     North America     USA  Massachusetts      NaN  Homo sapiens
# 2     North America     USA  Massachusetts      NaN  Homo sapiens
# 3     North America     USA  Massachusetts      NaN  Homo sapiens
# 4     North America     USA  Massachusetts      NaN  Homo sapiens
# ...             ...     ...            ...      ...           ...
# 8549  North America     USA  Massachusetts      NaN  Homo sapiens
# 8550  North America     USA  Massachusetts      NaN  Homo sapiens
# 8551  North America     USA  Massachusetts      NaN  Homo sapiens
# 8552  North America     USA  Massachusetts      NaN  Homo sapiens
# 8553  North America     USA  Massachusetts      NaN  Homo sapiens
#
#      date_submitted  ... missing_data divergence nonACGTN QC_missing_data  \
# 0        2022-11-24  ...       7537.0      589.0      7.0        mediocre
# 1        2022-11-24  ...       2189.0      597.0      1.0            good
# 2        2022-11-24  ...       1908.0      598.0      0.0            good
# 3        2022-11-24  ...       1566.0      599.0      0.0            good
# 4        2022-11-24  ...       2954.0      599.0      0.0            good
# ...             ...  ...          ...        ...      ...             ...
# 8549     2022-11-24  ...       1043.0      599.0      0.0            good
# 8550     2022-11-24  ...       2386.0      595.0      9.0            good
# 8551     2022-11-24  ...       2741.0      595.0      2.0            good
# 8552     2022-11-24  ...       1053.0      603.0      0.0            good
# 8553     2022-11-24  ...       3080.0      595.0      1.0            good
#
#      QC_mixed_sites QC_rare_mutations QC_frame_shifts  QC_stop_codons  \
# 0              good              good            good            good
# 1              good              good            good            good
# 2              good              good            good            good
# 3              good              good            good            good
# 4              good              good            good            good
# ...             ...               ...             ...             ...
# 8549           good              good            good            good
# 8550           good              good            good            good
# 8551           good              good            good            good
# 8552           good              good            good            good
# 8553           good              good            good            good
#
#         frame_shifts  is_reverse_complement
# 0     OPG023:386-661                  False
# 1                NaN                  False
# 2                NaN                  False
# 3                NaN                  False
# 4                NaN                  False
# ...              ...                    ...
# 8549             NaN                  False
# 8550   OPG038:62-221                  False
# 8551             NaN                  False
# 8552             NaN                  False
# 8553             NaN                  False
#
# [8554 rows x 28 columns]

# %%
metadata_for_build = metadata.copy()
metadata_for_build
metadata_for_build["focus_areas"] = metadata_for_build.region
metadata_for_build.focus_areas[metadata_for_build.focus_areas != "North America"] = "Global"
metadata_for_build.focus_areas[(metadata_for_build.institution.str.contains("Los Angeles")) & (metadata_for_build.country == "USA") ] = "Los Angeles County"
metadata_for_build.focus_areas[metadata_for_build.division == "New York" ] = "New York City"
metadata_for_build.focus_areas[(metadata_for_build.institution.str.contains("UW")) & (metadata_for_build.division == "Washington") ] = "Washington"
metadata_for_build.focus_areas[(metadata_for_build.institution.str.contains("CDPH")) & (metadata_for_build.country == "USA") ] = "Other California"
metadata_for_build.focus_areas[metadata_for_build.location == "Cook County IL"] = "Cook County"


#metadata_for_build.focus_areas.value_counts()
metadata_for_build.to_csv("metadata.tsv", sep = "\t")
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_67868/1254286902.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_for_build.focus_areas[metadata_for_build.focus_areas != "North America"] = "Global"
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_67868/1254286902.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_for_build.focus_areas[(metadata_for_build.institution.str.contains("Los Angeles")) & (metadata_for_build.country == "USA") ] = "Los Angeles County"
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_67868/1254286902.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_for_build.focus_areas[metadata_for_build.division == "New York" ] = "New York City"
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_67868/1254286902.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_for_build.focus_areas[(metadata_for_build.institution.str.contains("UW")) & (metadata_for_build.division == "Washington") ] = "Washington"
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_67868/1254286902.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_for_build.focus_areas[(metadata_for_build.institution.str.contains("CDPH")) & (metadata_for_build.country == "USA") ] = "Other California"
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_67868/1254286902.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_for_build.focus_areas[metadata_for_build.location == "Cook County IL"] = "Cook County"
