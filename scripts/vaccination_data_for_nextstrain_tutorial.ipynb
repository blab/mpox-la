# %%
import pandas as pd
import random

# %%
df = pd.read_csv("/Users/mparedes/Desktop/gitrepos/cdph_talk/ncov/results/california/metadata_filtered.tsv", sep = "\t")

# %%
df
# Out:
#                            strain            virus    gisaid_epi_isl  \
# 0                 Wuhan-Hu-1/2019             ncov    EPI_ISL_402125
# 1   USA/CA-GBW-GKPLAAAA14619/2024  betacoronavirus  EPI_ISL_19279738
# 2   USA/CA-GBW-GKISBBBD61152/2024  betacoronavirus  EPI_ISL_19289789
# 3   USA/CA-GBW-GKPLAAAA31953/2024  betacoronavirus  EPI_ISL_19289943
# 4   USA/CA-GBW-GKISBBBD35012/2024  betacoronavirus  EPI_ISL_19289798
# ..                            ...              ...               ...
# 73         USA/PR-CVL-025295/2024             ncov                 ?
# 74    USA/SC-CDC-QDX48247313/2023             ncov                 ?
# 75   USA/VIEW-L7259885894415/2024             ncov                 ?
# 76               USA/VSP0356/2020             ncov                 ?
# 77  USA/WA-GBW-GKPLAAAA22090/2024             ncov                 ?
#
#    genbank_accession genbank_accession_rev sra_accession        date  \
# ...

# %%
df = df[["strain", "division"]]
df.strain = [elem.replace("hCoV-19/", "") for elem in df.strain]
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_38357/2786627234.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.strain = [elem.replace("hCoV-19/", "") for elem in df.strain]

# %%
df
# Out:
#                            strain        division
# 0                 Wuhan-Hu-1/2019           China
# 1   USA/CA-GBW-GKPLAAAA14619/2024      California
# 2   USA/CA-GBW-GKISBBBD61152/2024      California
# 3   USA/CA-GBW-GKPLAAAA31953/2024      California
# 4   USA/CA-GBW-GKISBBBD35012/2024      California
# ..                            ...             ...
# 73         USA/PR-CVL-025295/2024     Puerto Rico
# 74    USA/SC-CDC-QDX48247313/2023  South Carolina
# 75   USA/VIEW-L7259885894415/2024       Tennessee
# 76               USA/VSP0356/2020    Pennsylvania
# 77  USA/WA-GBW-GKPLAAAA22090/2024      Washington
#
# [78 rows x 2 columns]

# %%
vac_list = ["vaccinated", "unvaccinated", "booster"]
df["vaccination"] = random.choices(vac_list, k = len(df))
# Out:
# /var/folders/h9/0347drb57tsgxzbddmvmlvf80000gp/T/ipykernel_38357/2355725765.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["vaccination"] = random.choices(vac_list, k = len(df))

# %%
df = df.set_index("strain")

# %%
df.to_csv("/Users/mparedes/Desktop/gitrepos/cdph_talk/example_vaccination_data.tsv", sep = "\t")
